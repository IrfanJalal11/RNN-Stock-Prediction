# %% [markdown]
# # **Imports**

# %%
# !pip install utils
# !pip install mxnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: utils in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mxnet in /usr/local/lib/python3.10/dist-packages (1.9.1)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.10/dist-packages (from mxnet) (1.22.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from mxnet) (2.27.1)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from mxnet) (0.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.20.0->mxnet) (3.4)

# %%
from pandas.testing import *

import time
import numpy as np
import pandas as pd

from mxnet import nd, autograd, gluon
from mxnet.gluon import nn, rnn
import mxnet as mx
import datetime
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA

import math

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
#from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings("ignore")

context = mx.cpu(); model_ctx=mx.cpu()
mx.random.seed(1719)

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
##All imports


import numpy as np
import os
import sys
import time
import io
import pandas as pd 
from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import logging
import plotly.graph_objects as go
# import talos as ta
from google.colab import files


##Other os related stuff
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
logging.getLogger("tensorflow").setLevel(logging.ERROR)
os.environ['TZ'] = 'Asia/Tehran'  # to set timezone; needed when running on cloud
time.tzset()

# %% [markdown]
# # **3. Data**

# %% [markdown]
# ## > **3.1. Correlated Assets**
# https://www.portfoliovisualizer.com/asset-correlations
# https://unicornbay.com/tools/most-less-correlated-assets

# %% [markdown]
# ### **3.1.1 Data Preparation**

# %%
def parser(x):
    return datetime.datetime.strptime(x,'%Y-%m-%d')

# %%
url = 'https://raw.githubusercontent.com/berserkhmdvhb/stockdata-public/master/ge.us.txt'
df_gs = pd.read_csv(url)

df_gs.drop(df_gs.columns[[1,2,3,5,6]], axis=1,inplace=True)
df_gs.columns = ['Date','GS']
df_gs['Date'] = pd.to_datetime(df_gs['Date'], format='%Y-%m-%d')

# %%
print(df_gs.head())
print(df_gs.tail(),'\n\n')
# Out:
#         Date      GS
# 0 1962-01-02  0.6201
# 1 1962-01-03  0.6201
# 2 1962-01-04  0.6122
# 3 1962-01-05  0.5957
# 4 1962-01-08  0.5957
#             Date     GS
# 14053 2017-11-06  20.13
# 14054 2017-11-07  20.21
# 14055 2017-11-08  20.12
# 14056 2017-11-09  19.99
# 14057 2017-11-10  20.49

# %%
df_gs.dropna()
# Out:
#             Date       GS
# 0     1962-01-02   0.6201
# 1     1962-01-03   0.6201
# 2     1962-01-04   0.6122
# 3     1962-01-05   0.5957
# 4     1962-01-08   0.5957
# ...          ...      ...
# 14053 2017-11-06  20.1300
# 14054 2017-11-07  20.2100
# 14055 2017-11-08  20.1200
# 14056 2017-11-09  19.9900
# 14057 2017-11-10  20.4900
#
# [14058 rows x 2 columns]

# %%
print('There are {} number of days in the dataset of General Electrics. \n'.format(df_gs.shape[0]))
# Out:
# There are 14058 number of days in the dataset of General Electrics.

# %%
df_train, df_test = train_test_split(df_gs, train_size=0.8, test_size=0.2, shuffle=False)
print("Train--Test size", len(df_train), len(df_test))
# Out:
# Train--Test size 11246 2812

# %%
df_gs.Date[11000]
# Out:
# Timestamp('2005-09-21 00:00:00')

# %%
#df_gs.set_index('Date', inplace=True)

# %%
#df_gs_b = df_gs.copy()

# %% [markdown]
# ### **3.1.2 Data Visualization**

# %%
##Visualize Correlated Stocks

###Visaulise 400 days
def plot_stocks(dataset1):
    plt.figure(figsize=(18, 5), dpi=100)
    shape_0 = dataset1.shape[0]

    #x_ = range(3, dataset.shape[0])
    #x_ =list(dataset.index)
    plt.plot(dataset1['Date'],dataset1.iloc[:, 1],color = 'g', label='General Electric stock')
    #plt.plot(dataset2['Date'], dataset2.iloc[:, 1],color = 'r', label='Goldman Sachs stock')
    #plt.plot(dataset3['Date'], dataset3.iloc[:, 1],color = 'c', label='Goldman Sachs stock')
    #plt.vlines(datetime.date(2005,9, 21), 0, 270, linestyles='--', colors='gray', label='Train/Test data cut-off')
    plt.vlines(datetime.date(2005,9,21), 0, 50, linestyles='--', colors='gray', label='Train/Test data cut-off')
    plt.xlabel('Date')
    plt.ylabel('USD')
    plt.title('Figure 2: General Electric stock price')
    plt.legend()
    plt.savefig('stock.png')
    plt.show()

# %%
plot_stocks(df_gs)

# %%
#files.download('stock.png')

# %% [markdown]
# ## **3.2. Technical Indicators**

# %%
## ma: Moving Average
## MACD: Moving Average Convergence Divergence
## ema: Exponential Moving Average
def get_technical_indicators(datasetinput):
    length = datasetinput.shape[0]
    dataset = datasetinput.copy()
    column_names = ['Date','Adj','ma7','ma21','26ema','20sd','upper_band','lower_band', 'ema']
    ndataset = pd.DataFrame (columns = column_names)
    ndataset['Adj'] = datasetinput.iloc[:, 1]
    ndataset['Date'] = datasetinput['Date']
    # Create 7 and 21 days Moving Average
    ndataset['ma7'] = ndataset.iloc[:, 1].rolling(window=7).mean()
    ndataset['ma21'] = ndataset.iloc[:, 1].rolling(window=21).mean()
    
    ## Create MACD
    #s = pd.Series(dataset['GS'])
    #ndataset['26ema'] = s.ewm(span=26)
    #ndataset['12ema'] = s.ewm(span=12)
    #ndataset['MACD'] = (ndataset['12ema']-ndataset['26ema'])
    
    #dataset['26ema'] = pd.ewma(dataset['price'], span=26)
    #dataset['12ema'] = pd.ewma(dataset['price'], span=12)
    #dataset['MACD'] = (dataset['12ema']-dataset['26ema'])

    ndataset['12ema'] = ndataset.iloc[:, 1].ewm(span=12, adjust=False).mean()
    ndataset['26ema'] = ndataset.iloc[:, 1].ewm(span=26, adjust=False).mean()
    #ndataset['MACD'] = (ndataset['12ema']- ndataset['26ema'])
    #exp3 = ndataset['MACD'].ewm(span=9, adjust=False).mean()

    ## Create Bollinger Bands
    ### set .std(ddof=0) for population std instead of sample
    #dataset['20sd'] = pd.stats.moments.rolling_std(dataset['GS'],20)
    #dataset['upper_band'] = dataset['ma21'] + (dataset['20sd']*2)
    #dataset['lower_band'] = dataset['ma21'] - (dataset['20sd']*2)
    ndataset['20sd'] = ndataset.iloc[:, 1].rolling(window=20).std() 
    ndataset['upper_band'] = ndataset['ma21'] + (ndataset['20sd'] * 2)
    ndataset['lower_band'] = ndataset['ma21'] - (ndataset['20sd'] * 2)

    
    ## Create Exponential moving average
    ndataset['ema'] = ndataset.iloc[:, 1].ewm(com=0.5).mean()
    
    ## Create Momentum
    #ndataset['momentum'] = ndataset.iloc[:, 1]-1
    #ndataset['log_momentum'] = np.log(ndataset['momentum'])

    ## Fill Missing Values
    ndataset['ma7'] = ndataset['ma7'].fillna(ndataset['ma7'].mean())
    ndataset['ma21'] = ndataset['ma21'].fillna(ndataset['ma21'].mean())
    ndataset['20sd'] = ndataset['20sd'].fillna(ndataset['20sd'].mean())
    ndataset['upper_band'] = ndataset['upper_band'].fillna(ndataset['upper_band'].mean())
    ndataset['lower_band'] = ndataset['lower_band'].fillna(ndataset['lower_band'].mean())
    return ndataset

# %%
dataset_TI_gs = get_technical_indicators(df_gs)

# %%
##Visaulise 400 days
def plot_technical_indicators(dataset, last_days):
    plt.figure(figsize=(16, 10), dpi=100)
    shape_0 = dataset.shape[0]
    xmacd_ = shape_0-last_days
    
    dataset = dataset.iloc[-last_days:, :]
    x_ = range(3, dataset.shape[0])
    x_ =list(dataset.index)
    

    plt.plot(dataset['ma7'],label='MA 7', color='g',linestyle='--')
    plt.plot(dataset.iloc[:, 1],label='Closing Price', color='b')
    plt.plot(dataset['ma21'],label='MA 21', color='r',linestyle='--')
    plt.plot(dataset['upper_band'],label='Upper Band', color='c')
    plt.plot(dataset['lower_band'],label='Lower Band', color='c')
    plt.fill_between(x_, dataset['lower_band'], dataset['upper_band'], alpha=0.35)
    plt.title('Technical indicators for Goldman Sachs - last {} days.'.format(last_days))
    plt.ylabel('USD')
    plt.legend()
    plt.savefig("inds.png")
    plt.show()

# %%
plot_technical_indicators(dataset_TI_gs, 400)

# %%
#files.download('in')

# %%
dataset_TI_gs
# Out:
#             Date      Adj        ma7       ma21      26ema      20sd  \
# 0     1962-01-02   0.6201  10.534214  10.534029   0.620100  0.268396
# 1     1962-01-03   0.6201  10.534214  10.534029   0.620100  0.268396
# 2     1962-01-04   0.6122  10.534214  10.534029   0.619515  0.268396
# 3     1962-01-05   0.5957  10.534214  10.534029   0.617751  0.268396
# 4     1962-01-08   0.5957  10.534214  10.534029   0.616117  0.268396
# ...          ...      ...        ...        ...        ...       ...
# 14053 2017-11-06  20.1300  20.227143  21.980476  22.005934  1.424942
# 14054 2017-11-07  20.2100  20.144286  21.827143  21.872902  1.430081
# 14055 2017-11-08  20.1200  20.102857  21.672857  21.743057  1.438929
# 14056 2017-11-09  19.9900  20.078571  21.526190  21.613201  1.439656
# 14057 2017-11-10  20.4900  20.145714  21.404286  21.530001  1.407691
#
#        upper_band  lower_band        ema      12ema
# 0       11.070858    9.997200   0.620100   0.620100
# 1       11.070858    9.997200   0.620100   0.620100
# 2       11.070858    9.997200   0.614631   0.618885
# 3       11.070858    9.997200   0.601853   0.615318
# 4       11.070858    9.997200   0.597734   0.612300
# ...           ...         ...        ...        ...
# 14053   24.830360   19.130593  20.117657  20.942840
# 14054   24.687305   18.966981  20.179219  20.830095
# 14055   24.550715   18.794999  20.139740  20.720850
# 14056   24.405503   18.646878  20.039913  20.608411
# 14057   24.219668   18.588903  20.339971  20.590194
#
# [14058 rows x 10 columns]

# %% [markdown]
# ##  ***3.4. Fourier transforms for trend analysis***

# %%
##Visualize Correlated Stocks

###Visaulise 400 days
def plot_fouriers(dataset):
    close_fft = np.fft.fft(np.asarray(dataset.iloc[:, 1].tolist()))
    fft_df = pd.DataFrame({'fft':close_fft})
    fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
    fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))
    plt.figure(figsize=(18, 5), dpi=100)
    fft_list = np.asarray(fft_df['fft'].tolist())
    for num_ in [3, 6, 9, 100]:
        fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
        plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))
    plt.plot(dataset.iloc[:, 0],  label='Real')
    plt.xlabel('Days')
    plt.ylabel('USD')
    plt.title('Figure 3: Goldman Sachs (close) stock prices & Fourier transforms')
    plt.legend()
    plt.show()

# %%
def fourier_tr(dataset,num_):
    close_fft = np.fft.fft(np.asarray(dataset.iloc[:, 1].tolist()))
    fft_df = pd.DataFrame({'fft':close_fft})
    fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
    fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))
    fft_list = np.asarray(fft_df['fft'].tolist())
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    return np.fft.ifft(fft_list_m10)

# %%
##Visualize Correlated Stocks

###Visaulise 400 days
def plot_fouriers(dataset,n1,n2,n3,n4):
    plt.figure(figsize=(18, 5), dpi=100)
    for num_ in [n1,n2,n3,n4]:
        plt.plot(fourier_tr(dataset,num_), label='Fourier transform with {} components'.format(num_))
    plt.plot(dataset.iloc[:, 1],  label='Real')
    plt.xlabel('Days')
    plt.ylabel('USD')
    plt.title('Figure 3: Goldman Sachs (close) stock prices & Fourier transforms')
    plt.legend()
    plt.savefig("four.png")
    plt.show()

# %%
plot_fouriers(df_gs,3, 6, 9, 100)

# %%
##Wavelet

#from collections import deque
#items = deque(np.asarray(fft_df['absolute'].tolist()))
#items.rotate(int(np.floor(len(fft_df)/2)))
#plt.figure(figsize=(10, 7), dpi=80)
#plt.stem(items)
#plt.title('Figure 4: Components of Fourier transforms')
#plt.show()

# %%
##Appending Fourier transforms of 3,6,9 to Features##
###GS
#dataset_TI_gs['Fourier3'] = fourier_tr(df_gs,3)
#dataset_TI_gs['Fourier6'] = fourier_tr(df_gs,6)
#dataset_TI_gs['Fourier9'] = fourier_tr(df_gs,9)

# %% [markdown]
# ## **3.7. Feature Engineering**

# %% [markdown]
# ### **3.7.0. Aggregate All Features**

# %%
dataset_total = dataset_TI_gs.copy()

# %%
print('Total dataset has {} samples, and {} features.'.format(dataset_total.shape[0], \
                                                              dataset_total.shape[1]))
# Out:
# Total dataset has 14058 samples, and 10 features.

# %%
dataset_total
# Out:
#             Date      Adj        ma7       ma21      26ema      20sd  \
# 0     1962-01-02   0.6201  10.534214  10.534029   0.620100  0.268396
# 1     1962-01-03   0.6201  10.534214  10.534029   0.620100  0.268396
# 2     1962-01-04   0.6122  10.534214  10.534029   0.619515  0.268396
# 3     1962-01-05   0.5957  10.534214  10.534029   0.617751  0.268396
# 4     1962-01-08   0.5957  10.534214  10.534029   0.616117  0.268396
# ...          ...      ...        ...        ...        ...       ...
# 14053 2017-11-06  20.1300  20.227143  21.980476  22.005934  1.424942
# 14054 2017-11-07  20.2100  20.144286  21.827143  21.872902  1.430081
# 14055 2017-11-08  20.1200  20.102857  21.672857  21.743057  1.438929
# 14056 2017-11-09  19.9900  20.078571  21.526190  21.613201  1.439656
# 14057 2017-11-10  20.4900  20.145714  21.404286  21.530001  1.407691
#
#        upper_band  lower_band        ema      12ema
# 0       11.070858    9.997200   0.620100   0.620100
# 1       11.070858    9.997200   0.620100   0.620100
# 2       11.070858    9.997200   0.614631   0.618885
# 3       11.070858    9.997200   0.601853   0.615318
# 4       11.070858    9.997200   0.597734   0.612300
# ...           ...         ...        ...        ...
# 14053   24.830360   19.130593  20.117657  20.942840
# 14054   24.687305   18.966981  20.179219  20.830095
# 14055   24.550715   18.794999  20.139740  20.720850
# 14056   24.405503   18.646878  20.039913  20.608411
# 14057   24.219668   18.588903  20.339971  20.590194
#
# [14058 rows x 10 columns]

# %%
len(dataset_total.columns)
# Out:
# 10

# %% [markdown]
# ### **3.7.1. Feature importance with XGBoost**

# %%
dataset_total.set_index('Date', inplace=True)
#dataset_TI_gs.set_index('Date', inplace=True)

# %%
def get_feature_importance_data(data_income):
    data = data_income.copy()
    y = data['Adj']
    X = data.iloc[:, 1:]
    
    train_samples = int(X.shape[0] * 0.65)
 
    X_train = X.iloc[:train_samples]
    X_test = X.iloc[train_samples:]

    y_train = y.iloc[:train_samples]
    y_test = y.iloc[train_samples:]
    
    return (X_train, y_train), (X_test, y_test)

# %%
# Get training and test data
(X_train_FI, y_train_FI), (X_test_FI, y_test_FI) = get_feature_importance_data(dataset_total)
regressor = xgb.XGBRegressor(gamma=0.0,n_estimators=100,base_score=0.9,colsample_bytree=1,learning_rate=0.14)

# %%
xgbModel = regressor.fit(X_train_FI,y_train_FI, \
                         eval_set = [(X_train_FI, y_train_FI), (X_test_FI, y_test_FI)], \
                         verbose=False)

# %%
eval_result = regressor.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.xlabel('Iterations')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
plt.xticks(rotation='vertical')
plt.bar([i for i in range(len(xgbModel.feature_importances_))], xgbModel.feature_importances_.tolist(), tick_label=X_test_FI.columns)
plt.title('Figure 6: Feature importance of the technical indicators.')
plt.show()

# %%
len(dataset_total.columns)
# Out:
# 9

# %% [markdown]
# # **4.Bi-LSTM**

# %%
##Hypter Parameters' Range
params = {
    "batch_size": 20,  # 20<16<10, 25 was a bust
    "epochs": 300,
    "lr": 0.000010000,
    "time_steps": 60
}

iter_changes = "dropout_layers_0.4_0.4"

# %%
import shutil

## Create output path
OUTPUT_PATH = 'drive/MyDrive/Kuliah/MLProject' + iter_changes
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]
stime = time.time()

## Override existing directory
if os.path.exists(OUTPUT_PATH):
    shutil.rmtree(OUTPUT_PATH)
os.makedirs(OUTPUT_PATH)
print("Directory created/overridden:", OUTPUT_PATH)

def print_time(text, stime):
    seconds = (time.time()-stime)
    print(text, seconds//60,"minutes : ",np.round(seconds%60),"seconds")

print_time("Elapsed time:", stime)
# Out:
# Directory created/overridden: drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4
# Elapsed time: 0.0 minutes :  0.0 seconds

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
##Trim dataset based on batch size    
    
def trim_dataset(mat,batch_size):
    """
    trims dataset to a size that's divisible by BATCH_SIZE
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if no_of_rows_drop > 0:
        return mat[:-no_of_rows_drop]
    else:
        return mat
##Build timeseries based on time steps (For example if we have 3 time steps, we want our network to look back on 3 days of data to predict price on 4th day)

def build_timeseries(mat, y_col_index):
    """
    Converts ndarray into timeseries format and supervised data format. Takes first TIME_STEPS
    number of rows as input and sets the TIME_STEPS+1th data as corresponding output and so on.
    :param mat: ndarray which holds the dataset
    :param y_col_index: index of column which acts as output
    :return: returns two ndarrays-- input and output in format suitable to feed
    to LSTM.
    """
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))
    print("dim_0",dim_0)
    for i in tqdm_notebook(range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
#         if i < 10:
#           print(i,"-->", x[i,-1,:], y[i])
    print("length of time-series i/o",x.shape,y.shape)
    return x, y

# %%
df_train
# Out:
#             Date       GS
# 0     1962-01-02   0.6201
# 1     1962-01-03   0.6201
# 2     1962-01-04   0.6122
# 3     1962-01-05   0.5957
# 4     1962-01-08   0.5957
# ...          ...      ...
# 11241 2006-09-06  27.3340
# 11242 2006-09-07  27.4050
# 11243 2006-09-08  27.3820
# 11244 2006-09-11  27.7180
# 11245 2006-09-12  27.9120
#
# [11246 rows x 2 columns]

# %%
df_test
# Out:
#             Date      GS
# 11246 2006-09-13  28.049
# 11247 2006-09-14  28.003
# 11248 2006-09-15  28.058
# 11249 2006-09-18  28.073
# 11250 2006-09-19  28.058
# ...          ...     ...
# 14053 2017-11-06  20.130
# 14054 2017-11-07  20.210
# 14055 2017-11-08  20.120
# 14056 2017-11-09  19.990
# 14057 2017-11-10  20.490
#
# [2812 rows x 2 columns]

# %%
## split
L = []
for i in range(9):
  L.append(i)
##


df_train, df_test = train_test_split(dataset_total.iloc[:,L], train_size=0.8, test_size=0.2, shuffle=False)
print("Train--Test size", len(df_train), len(df_test))
# scale the feature MinMax, build array
x = df_train.iloc[:,L].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.iloc[:,L])

#print("Deleting unused dataframes of total size(KB)",(sys.getsizeof(df_ge)+sys.getsizeof(df_train)+sys.getsizeof(df_test))//1024)

#del dataset_total
#del df_test
#del df_train
#del x

print("Are any NaNs present in train/test matrices?",np.isnan(x_train).any(), np.isnan(x_train).any())
x_t, y_t = build_timeseries(x_train, 0)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
print("Batch trimmed size",x_t.shape, y_t.shape)
# Out:
# Train--Test size 11246 2812
# Are any NaNs present in train/test matrices? False False
# dim_0 11186
#   0%|          | 0/11186 [00:00<?, ?it/s]
# length of time-series i/o (11186, 60, 9) (11186,)
# Batch trimmed size (11180, 60, 9) (11180,)

# %%
x_train.shape
# Out:
# (11246, 9)

# %%
x_test.shape
# Out:
# (2812, 9)

# %%
x_temp, y_temp = build_timeseries(x_test, 0)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)
# Out:
# dim_0 2752
#   0%|          | 0/2752 [00:00<?, ?it/s]
# length of time-series i/o (2752, 60, 9) (2752,)

# %%
tt = trim_dataset(x_test_t, BATCH_SIZE)
ytt = y_test_t 
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)

# %%
ytt.shape
# Out:
# (1370,)

# %%
tt.shape
# Out:
# (1360, 60, 9)

# %%
y_test_t.shape
# Out:
# (1360,)

# %%
from keras.layers import Bidirectional

def create_bilstm_model():
    bilstm_model = Sequential()
    # (batch_size, timesteps, data_dim)
    bilstm_model.add(Bidirectional(LSTM(100, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
                                        dropout=0.0, recurrent_dropout=0.0, stateful=True, return_sequences=True,
                                        kernel_initializer='random_uniform')))
    bilstm_model.add(Dropout(0.4))
    bilstm_model.add(Bidirectional(LSTM(60, dropout=0.0)))
    bilstm_model.add(Dropout(0.4))
    bilstm_model.add(Dense(20, activation='relu'))
    bilstm_model.add(Dense(1, activation='sigmoid'))
    optimizer = optimizers.RMSprop(lr=params["lr"])
    # optimizer = optimizers.SGD(lr=0.000001, decay=1e-6, momentum=0.9, nesterov=True)
    bilstm_model.compile(loss='mean_squared_error', optimizer=optimizer)
    return bilstm_model

bilstm_model = create_bilstm_model()

model = None
try:
    model = pickle.load(open("bilstm_model", 'rb'))
    print("Loaded saved model...")
except FileNotFoundError:
    print("Model not found")


x_temp, y_temp = build_timeseries(x_test, 0)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)

print("Test size", x_test_t.shape, y_test_t.shape, x_val.shape, y_val.shape)
    
is_update_model = True
if model is None or is_update_model:
    from keras import backend as K
    print("Building model...")
    #print("checking if GPU available", K.tensorflow_backend._get_available_gpus())
    model = create_bilstm_model()
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                       patience=40, min_delta=0.0001)
    
    mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
                          "best_model.h5"), monitor='val_loss', verbose=1,
                          save_best_only=True, save_weights_only=False, mode='min', period=1)

    # Not used here. But leaving it here as a reminder for future
    r_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=30, 
                                  verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)
    
    csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
# Out:
# Model not found
# dim_0 2752
#   0%|          | 0/2752 [00:00<?, ?it/s]
# length of time-series i/o (2752, 60, 9) (2752,)
# Test size (1370, 60, 9) (1370,) (1370, 60, 9) (1370,)
# Building model...

# %%
  
history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
                    shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
                    trim_dataset(y_val, BATCH_SIZE)), callbacks=[es, mcp, csv_logger])

print("saving model...")
pickle.dump(model, open("bilstm_model", "wb"))
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.04584, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 121s - loss: 0.1743 - val_loss: 0.0458 - 121s/epoch - 216ms/step
# Epoch 2/300
#
# Epoch 2: val_loss improved from 0.04584 to 0.03835, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 81s - loss: 0.1035 - val_loss: 0.0384 - 81s/epoch - 145ms/step
# Epoch 3/300
#
# Epoch 3: val_loss improved from 0.03835 to 0.02099, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 80s - loss: 0.0511 - val_loss: 0.0210 - 80s/epoch - 143ms/step
# Epoch 4/300
#
# Epoch 4: val_loss improved from 0.02099 to 0.01707, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 84s - loss: 0.0216 - val_loss: 0.0171 - 84s/epoch - 151ms/step
# Epoch 5/300
#
# Epoch 5: val_loss improved from 0.01707 to 0.00315, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 78s - loss: 0.0051 - val_loss: 0.0032 - 78s/epoch - 139ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 0.00315
# 559/559 - 79s - loss: 0.0021 - val_loss: 0.0068 - 79s/epoch - 141ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 0.00315
# 559/559 - 87s - loss: 0.0017 - val_loss: 0.0074 - 87s/epoch - 155ms/step
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 0.00315
# 559/559 - 79s - loss: 0.0016 - val_loss: 0.0079 - 79s/epoch - 142ms/step
# Epoch 9/300
#
# Epoch 9: val_loss did not improve from 0.00315
# 559/559 - 83s - loss: 0.0015 - val_loss: 0.0081 - 83s/epoch - 148ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 0.00315
# 559/559 - 79s - loss: 0.0015 - val_loss: 0.0068 - 79s/epoch - 142ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 0.00315
# 559/559 - 77s - loss: 0.0014 - val_loss: 0.0062 - 77s/epoch - 138ms/step
# Epoch 12/300
#
# Epoch 12: val_loss did not improve from 0.00315
# 559/559 - 77s - loss: 0.0014 - val_loss: 0.0055 - 77s/epoch - 138ms/step
# Epoch 13/300
#
# Epoch 13: val_loss did not improve from 0.00315
# 559/559 - 77s - loss: 0.0013 - val_loss: 0.0057 - 77s/epoch - 138ms/step
# Epoch 14/300
#
# Epoch 14: val_loss did not improve from 0.00315
# 559/559 - 88s - loss: 0.0013 - val_loss: 0.0051 - 88s/epoch - 157ms/step
# Epoch 15/300
#
# Epoch 15: val_loss did not improve from 0.00315
# 559/559 - 93s - loss: 0.0013 - val_loss: 0.0045 - 93s/epoch - 166ms/step
# Epoch 16/300
#
# Epoch 16: val_loss did not improve from 0.00315
# 559/559 - 96s - loss: 0.0013 - val_loss: 0.0042 - 96s/epoch - 172ms/step
# Epoch 17/300
#
# Epoch 17: val_loss did not improve from 0.00315
# 559/559 - 111s - loss: 0.0013 - val_loss: 0.0043 - 111s/epoch - 199ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 0.00315
# 559/559 - 100s - loss: 0.0012 - val_loss: 0.0040 - 100s/epoch - 178ms/step
# Epoch 19/300
#
# Epoch 19: val_loss did not improve from 0.00315
# 559/559 - 97s - loss: 0.0012 - val_loss: 0.0036 - 97s/epoch - 174ms/step
# Epoch 20/300
#
# Epoch 20: val_loss did not improve from 0.00315
# 559/559 - 95s - loss: 0.0012 - val_loss: 0.0037 - 95s/epoch - 171ms/step
# Epoch 21/300
#
# Epoch 21: val_loss did not improve from 0.00315
# 559/559 - 93s - loss: 0.0012 - val_loss: 0.0035 - 93s/epoch - 167ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.00315
# 559/559 - 94s - loss: 0.0011 - val_loss: 0.0032 - 94s/epoch - 168ms/step
# Epoch 23/300
#
# Epoch 23: val_loss improved from 0.00315 to 0.00314, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 90s - loss: 0.0012 - val_loss: 0.0031 - 90s/epoch - 161ms/step
# Epoch 24/300
#
# Epoch 24: val_loss improved from 0.00314 to 0.00293, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 87s - loss: 0.0012 - val_loss: 0.0029 - 87s/epoch - 156ms/step
# Epoch 25/300
#
# Epoch 25: val_loss did not improve from 0.00293
# 559/559 - 93s - loss: 0.0011 - val_loss: 0.0030 - 93s/epoch - 167ms/step
# Epoch 26/300
#
# Epoch 26: val_loss improved from 0.00293 to 0.00290, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 92s - loss: 0.0012 - val_loss: 0.0029 - 92s/epoch - 165ms/step
# Epoch 27/300
#
# Epoch 27: val_loss improved from 0.00290 to 0.00275, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 87s - loss: 0.0011 - val_loss: 0.0028 - 87s/epoch - 156ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 0.00275 to 0.00267, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 93s - loss: 0.0011 - val_loss: 0.0027 - 93s/epoch - 166ms/step
# Epoch 29/300
#
# Epoch 29: val_loss improved from 0.00267 to 0.00262, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 94s - loss: 0.0011 - val_loss: 0.0026 - 94s/epoch - 169ms/step
# Epoch 30/300
#
# Epoch 30: val_loss improved from 0.00262 to 0.00253, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 102s - loss: 0.0011 - val_loss: 0.0025 - 102s/epoch - 182ms/step
# Epoch 31/300
#
# Epoch 31: val_loss improved from 0.00253 to 0.00249, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 83s - loss: 0.0011 - val_loss: 0.0025 - 83s/epoch - 148ms/step
# Epoch 32/300
#
# Epoch 32: val_loss improved from 0.00249 to 0.00245, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0024 - 77s/epoch - 137ms/step
# Epoch 33/300
#
# Epoch 33: val_loss improved from 0.00245 to 0.00232, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0023 - 77s/epoch - 138ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 0.00232
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0023 - 77s/epoch - 138ms/step
# Epoch 35/300
#
# Epoch 35: val_loss improved from 0.00232 to 0.00224, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 79s - loss: 0.0011 - val_loss: 0.0022 - 79s/epoch - 142ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 0.00224 to 0.00220, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0022 - 77s/epoch - 138ms/step
# Epoch 37/300
#
# Epoch 37: val_loss improved from 0.00220 to 0.00216, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0022 - 77s/epoch - 139ms/step
# Epoch 38/300
#
# Epoch 38: val_loss improved from 0.00216 to 0.00214, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 80s - loss: 0.0011 - val_loss: 0.0021 - 80s/epoch - 143ms/step
# Epoch 39/300
#
# Epoch 39: val_loss improved from 0.00214 to 0.00213, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 79s - loss: 0.0010 - val_loss: 0.0021 - 79s/epoch - 142ms/step
# Epoch 40/300
#
# Epoch 40: val_loss improved from 0.00213 to 0.00210, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0021 - 77s/epoch - 137ms/step
# Epoch 41/300
#
# Epoch 41: val_loss improved from 0.00210 to 0.00207, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0011 - val_loss: 0.0021 - 77s/epoch - 138ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.00207
# 559/559 - 76s - loss: 0.0010 - val_loss: 0.0021 - 76s/epoch - 136ms/step
# Epoch 43/300
#
# Epoch 43: val_loss improved from 0.00207 to 0.00205, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 80s - loss: 0.0010 - val_loss: 0.0020 - 80s/epoch - 144ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.00205
# 559/559 - 77s - loss: 0.0010 - val_loss: 0.0021 - 77s/epoch - 139ms/step
# Epoch 45/300
#
# Epoch 45: val_loss improved from 0.00205 to 0.00204, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0010 - val_loss: 0.0020 - 77s/epoch - 138ms/step
# Epoch 46/300
#
# Epoch 46: val_loss improved from 0.00204 to 0.00202, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0010 - val_loss: 0.0020 - 77s/epoch - 138ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.00202
# 559/559 - 79s - loss: 0.0010 - val_loss: 0.0021 - 79s/epoch - 141ms/step
# Epoch 48/300
#
# Epoch 48: val_loss improved from 0.00202 to 0.00201, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 0.0010 - val_loss: 0.0020 - 77s/epoch - 138ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 0.00201
# 559/559 - 78s - loss: 0.0010 - val_loss: 0.0021 - 78s/epoch - 140ms/step
# Epoch 50/300
#
# Epoch 50: val_loss improved from 0.00201 to 0.00195, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 78s - loss: 9.8431e-04 - val_loss: 0.0020 - 78s/epoch - 140ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 0.00195 to 0.00195, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 79s - loss: 0.0010 - val_loss: 0.0020 - 79s/epoch - 142ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.00195
# 559/559 - 77s - loss: 9.9610e-04 - val_loss: 0.0020 - 77s/epoch - 137ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.00195
# 559/559 - 77s - loss: 9.8174e-04 - val_loss: 0.0020 - 77s/epoch - 137ms/step
# Epoch 54/300
#
# Epoch 54: val_loss improved from 0.00195 to 0.00190, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 82s - loss: 9.8865e-04 - val_loss: 0.0019 - 82s/epoch - 147ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.00190
# 559/559 - 77s - loss: 9.8226e-04 - val_loss: 0.0021 - 77s/epoch - 137ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.00190
# 559/559 - 82s - loss: 9.8063e-04 - val_loss: 0.0020 - 82s/epoch - 147ms/step
# Epoch 57/300
#
# Epoch 57: val_loss improved from 0.00190 to 0.00190, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 81s - loss: 9.9604e-04 - val_loss: 0.0019 - 81s/epoch - 145ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.00190
# 559/559 - 80s - loss: 9.9265e-04 - val_loss: 0.0020 - 80s/epoch - 144ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.00190
# 559/559 - 77s - loss: 9.6324e-04 - val_loss: 0.0021 - 77s/epoch - 137ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.00190
# 559/559 - 77s - loss: 9.2632e-04 - val_loss: 0.0020 - 77s/epoch - 137ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.00190
# 559/559 - 77s - loss: 9.4380e-04 - val_loss: 0.0021 - 77s/epoch - 138ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.00190
# 559/559 - 80s - loss: 9.2068e-04 - val_loss: 0.0020 - 80s/epoch - 143ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.00190
# 559/559 - 78s - loss: 9.2070e-04 - val_loss: 0.0020 - 78s/epoch - 140ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.00190
# 559/559 - 78s - loss: 9.0477e-04 - val_loss: 0.0020 - 78s/epoch - 139ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.00190
# 559/559 - 79s - loss: 9.2186e-04 - val_loss: 0.0020 - 79s/epoch - 141ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.00190
# 559/559 - 79s - loss: 9.2333e-04 - val_loss: 0.0020 - 79s/epoch - 142ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.00190
# 559/559 - 77s - loss: 8.7260e-04 - val_loss: 0.0021 - 77s/epoch - 137ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.00190
# 559/559 - 79s - loss: 8.7444e-04 - val_loss: 0.0020 - 79s/epoch - 142ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.00190
# 559/559 - 77s - loss: 8.6921e-04 - val_loss: 0.0019 - 77s/epoch - 139ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.00190
# 559/559 - 79s - loss: 8.4169e-04 - val_loss: 0.0020 - 79s/epoch - 141ms/step
# Epoch 71/300
#
# Epoch 71: val_loss improved from 0.00190 to 0.00187, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 80s - loss: 8.3283e-04 - val_loss: 0.0019 - 80s/epoch - 143ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.00187
# 559/559 - 77s - loss: 8.1624e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.00187
# 559/559 - 77s - loss: 7.8015e-04 - val_loss: 0.0020 - 77s/epoch - 138ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.00187
# 559/559 - 78s - loss: 7.7936e-04 - val_loss: 0.0021 - 78s/epoch - 139ms/step
# Epoch 75/300
#
# Epoch 75: val_loss improved from 0.00187 to 0.00172, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 7.9883e-04 - val_loss: 0.0017 - 77s/epoch - 138ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.00172
# 559/559 - 80s - loss: 7.6906e-04 - val_loss: 0.0019 - 80s/epoch - 143ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.00172
# 559/559 - 77s - loss: 7.5941e-04 - val_loss: 0.0018 - 77s/epoch - 138ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.00172
# 559/559 - 77s - loss: 7.7456e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.00172
# 559/559 - 77s - loss: 7.4091e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.00172
# 559/559 - 77s - loss: 7.4260e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.00172
# 559/559 - 77s - loss: 7.1534e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.00172
# 559/559 - 79s - loss: 7.0619e-04 - val_loss: 0.0018 - 79s/epoch - 142ms/step
# Epoch 83/300
#
# Epoch 83: val_loss improved from 0.00172 to 0.00170, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 78s - loss: 7.1042e-04 - val_loss: 0.0017 - 78s/epoch - 139ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.00170
# 559/559 - 77s - loss: 6.9165e-04 - val_loss: 0.0018 - 77s/epoch - 138ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.00170
# 559/559 - 77s - loss: 6.9702e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.00170
# 559/559 - 77s - loss: 6.8067e-04 - val_loss: 0.0018 - 77s/epoch - 138ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.00170
# 559/559 - 78s - loss: 6.8267e-04 - val_loss: 0.0019 - 78s/epoch - 139ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.00170
# 559/559 - 80s - loss: 6.6588e-04 - val_loss: 0.0022 - 80s/epoch - 142ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.00170
# 559/559 - 78s - loss: 6.5746e-04 - val_loss: 0.0018 - 78s/epoch - 139ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.00170
# 559/559 - 78s - loss: 6.4121e-04 - val_loss: 0.0018 - 78s/epoch - 139ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.00170
# 559/559 - 77s - loss: 6.2294e-04 - val_loss: 0.0021 - 77s/epoch - 139ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.00170
# 559/559 - 77s - loss: 6.3615e-04 - val_loss: 0.0018 - 77s/epoch - 138ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.00170
# 559/559 - 78s - loss: 6.3160e-04 - val_loss: 0.0021 - 78s/epoch - 140ms/step
# Epoch 94/300
#
# Epoch 94: val_loss improved from 0.00170 to 0.00160, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 79s - loss: 6.3690e-04 - val_loss: 0.0016 - 79s/epoch - 141ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.00160
# 559/559 - 77s - loss: 6.0930e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.00160
# 559/559 - 77s - loss: 6.3598e-04 - val_loss: 0.0019 - 77s/epoch - 138ms/step
# Epoch 97/300
#
# Epoch 97: val_loss improved from 0.00160 to 0.00151, saving model to drive/MyDrive/Kuliah/MLProjectdropout_layers_0.4_0.4/best_model.h5
# 559/559 - 77s - loss: 6.0251e-04 - val_loss: 0.0015 - 77s/epoch - 138ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.9509e-04 - val_loss: 0.0017 - 77s/epoch - 138ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.9671e-04 - val_loss: 0.0020 - 78s/epoch - 139ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.00151
# 559/559 - 80s - loss: 5.9266e-04 - val_loss: 0.0017 - 80s/epoch - 142ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.9271e-04 - val_loss: 0.0018 - 77s/epoch - 138ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 6.2367e-04 - val_loss: 0.0021 - 77s/epoch - 137ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 6.0241e-04 - val_loss: 0.0021 - 77s/epoch - 138ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.9965e-04 - val_loss: 0.0022 - 77s/epoch - 138ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.7873e-04 - val_loss: 0.0023 - 77s/epoch - 138ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.8630e-04 - val_loss: 0.0019 - 78s/epoch - 139ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 6.0486e-04 - val_loss: 0.0018 - 78s/epoch - 140ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.7816e-04 - val_loss: 0.0022 - 78s/epoch - 139ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.00151
# 559/559 - 81s - loss: 5.9567e-04 - val_loss: 0.0022 - 81s/epoch - 145ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.7051e-04 - val_loss: 0.0023 - 78s/epoch - 139ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.00151
# 559/559 - 80s - loss: 5.6802e-04 - val_loss: 0.0020 - 80s/epoch - 143ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.8842e-04 - val_loss: 0.0020 - 78s/epoch - 139ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.8941e-04 - val_loss: 0.0021 - 78s/epoch - 140ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.6734e-04 - val_loss: 0.0024 - 78s/epoch - 140ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.9682e-04 - val_loss: 0.0021 - 78s/epoch - 140ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.00151
# 559/559 - 79s - loss: 5.6139e-04 - val_loss: 0.0024 - 79s/epoch - 141ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 6.0235e-04 - val_loss: 0.0024 - 77s/epoch - 139ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.6591e-04 - val_loss: 0.0025 - 78s/epoch - 139ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.7185e-04 - val_loss: 0.0025 - 77s/epoch - 138ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.4633e-04 - val_loss: 0.0025 - 77s/epoch - 138ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.8214e-04 - val_loss: 0.0027 - 78s/epoch - 139ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.00151
# 559/559 - 79s - loss: 5.6352e-04 - val_loss: 0.0027 - 79s/epoch - 142ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.00151
# 559/559 - 79s - loss: 5.4608e-04 - val_loss: 0.0026 - 79s/epoch - 142ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.00151
# 559/559 - 77s - loss: 5.5528e-04 - val_loss: 0.0025 - 77s/epoch - 139ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.7012e-04 - val_loss: 0.0026 - 78s/epoch - 139ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.00151
# 559/559 - 83s - loss: 5.7401e-04 - val_loss: 0.0033 - 83s/epoch - 149ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.7298e-04 - val_loss: 0.0031 - 78s/epoch - 139ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.7807e-04 - val_loss: 0.0032 - 78s/epoch - 139ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.5134e-04 - val_loss: 0.0032 - 78s/epoch - 140ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.00151
# 559/559 - 81s - loss: 5.6275e-04 - val_loss: 0.0030 - 81s/epoch - 145ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.00151
# 559/559 - 79s - loss: 5.9301e-04 - val_loss: 0.0031 - 79s/epoch - 141ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.6982e-04 - val_loss: 0.0037 - 78s/epoch - 139ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.00151
# 559/559 - 78s - loss: 5.8725e-04 - val_loss: 0.0036 - 78s/epoch - 139ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.00151
# 559/559 - 80s - loss: 5.9131e-04 - val_loss: 0.0038 - 80s/epoch - 143ms/step
# Epoch 134: early stopping
# saving model...

# %%
# model.evaluate(x_test_t, y_test_t, batch_size=BATCH_SIZE
y_pred = model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
MSEE = mean_squared_error(y_test_t, y_pred)
r2score = r2_score(y_test_t, y_pred)
print("MSE is", MSEE, y_pred.shape, y_test_t.shape)
print("R2 is", r2score, y_pred.shape, y_test_t.shape)

print(y_pred[0:15])
print(y_test_t[0:15])
# Out:
# 68/68 [==============================] - 5s 45ms/step
# MSE is 0.000645862166231847 (1360,) (1360,)
# R2 is 0.905240131489012 (1360,) (1360,)
# [0.36318848 0.36206484 0.36102355 0.36009115 0.35925788 0.35860428
#  0.35818005 0.35775623 0.35754073 0.3573537  0.3572854  0.357073
#  0.3566533  0.35616603 0.35584098]
# [0.32378063 0.32499919 0.32800358 0.32905407 0.32905407 0.33031465
#  0.32943225 0.33205846 0.32659593 0.32747834 0.31770881 0.31092267
#  0.31258244 0.32378063 0.32592362]

# %%
# convert the predicted value to range of real data
y_pred_org = (y_pred * min_max_scaler.data_range_[0]) + min_max_scaler.data_min_[0]
# min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[0]) + min_max_scaler.data_min_[0]
# min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# [17.745695 17.692213 17.64265  17.598272 17.55861  17.527502 17.507309
#  17.487137 17.47688  17.467978 17.464727 17.454618 17.43464  17.41145
#  17.395977]
# [15.87  15.928 16.071 16.121 16.121 16.181 16.139 16.264 16.004 16.046
#  15.581 15.258 15.337 15.87  15.972]

# %%
# Visualize the training data
from matplotlib import pyplot as plt
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('train-val-loss.png')
plt.show()

# %%
files.download('train-val-loss.png')

# %%
# load the saved best model from above
saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) # , "lstm_best_7-3-19_12AM",
print(saved_model)

y_pred = saved_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])
y_pred_org = (y_pred * min_max_scaler.data_range_[0]) + min_max_scaler.data_min_[0] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[0]) + min_max_scaler.data_min_[0] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])
# Out:
# <keras.engine.sequential.Sequential object at 0x7f851a225d50>
# 68/68 [==============================] - 5s 37ms/step
# Error is 0.0006171760224868881 (1360,) (1360,)
# [0.44461352 0.44453275 0.4445305  0.44462845 0.4448119  0.44506344
#  0.44537327 0.4456781  0.44605443 0.44631034 0.44650218 0.4464827
#  0.44633278 0.44607335 0.44577977]
# [0.32378063 0.32499919 0.32800358 0.32905407 0.32905407 0.33031465
#  0.32943225 0.33205846 0.32659593 0.32747834 0.31770881 0.31092267
#  0.31258244 0.32378063 0.32592362]
# [21.621283 21.617437 21.61733  21.621992 21.630724 21.642696 21.657444
#  21.671953 21.689865 21.702045 21.711176 21.710249 21.703114 21.690765
#  21.676792]
# [15.87  15.928 16.071 16.121 16.121 16.181 16.139 16.264 16.004 16.046
#  15.581 15.258 15.337 15.87  15.972]

# %%
# Visualize the prediction
from matplotlib import pyplot as plt
plt.figure()
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
plt.savefig('result-pred.png')
plt.show()

print_time("program completed ", stime)
# Out:
# program completed  181.0 minutes :  11.0 seconds

# %%
files.download('result-pred.png')

# %%
y_pred_org[300:3500]
# Out:
# array([21.779217, 21.863142, 21.938477, ..., 25.391607, 25.422693,
#        25.43704 ], dtype=float32)

# %%
y_test_t_org[300:3500]
# Out:
# array([21.25 , 21.154, 21.37 , ..., 23.43 , 23.36 , 23.07 ])

# %%
#fig = px.line(df_gs, y=y_test_t_org,text='Real')
fig = go.Figure()
fig.add_scatter(y=y_test_t_org, mode='lines',name='Real')
fig.add_scatter(y=y_pred_org, mode='lines',name='Prediction')

fig.show()



# Show plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="430f9d61-9ac7-46e0-aea7-a95b56872280" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("430f9d61-9ac7-46e0-aea7-a95b56872280")) {                    Plotly.newPlot(                        "430f9d61-9ac7-46e0-aea7-a95b56872280",                        [{"mode":"lines","name":"Real","y":[15.87,15.928,16.071,16.121,16.121,16.181,16.139,16.264,16.003999999999998,16.046,15.581,15.257999999999997,15.337,15.87,15.972,16.141,16.063,16.377,16.285,16.575999999999997,16.81,16.598999999999997,16.81,16.894999999999996,16.556,16.792999999999996,16.548,16.785,17.065,17.123999999999995,17.665,17.369999999999997,17.316999999999997,17.233,16.954999999999995,16.987999999999996,16.631999999999998,16.683,16.478999999999996,16.761,16.605999999999998,16.716999999999995,16.819,16.785,16.843999999999998,17.030999999999995,16.927,16.954999999999995,17.427999999999997,17.736,17.634,17.589999999999996,17.571999999999996,17.397999999999996,17.77,17.777999999999995,17.902,17.809,17.854999999999997,17.887999999999998,17.791,17.752999999999997,17.77,17.845999999999997,17.798999999999996,17.743999999999996,17.671999999999997,17.616999999999997,17.498,17.634,17.671999999999997,17.644,17.652,17.498,17.554999999999996,17.388999999999996,17.505999999999997,18.064999999999998,18.299999999999997,18.207999999999995,18.299999999999997,18.556999999999995,18.666999999999998,18.743999999999996,18.693,18.854,19.013999999999996,19.16,19.245999999999995,19.098999999999997,19.058,18.878,19.416,19.398,19.484999999999996,19.466999999999995,19.567999999999998,19.604999999999997,19.749999999999996,19.577999999999996,19.321999999999996,19.16,19.227,19.202,19.339,19.339,19.567999999999998,19.484999999999996,18.817999999999998,18.535999999999998,18.176999999999996,18.159999999999997,18.159999999999997,18.032,17.99,18.228999999999996,18.200999999999997,18.286999999999995,18.441999999999997,18.048999999999996,17.845,17.938,17.845,17.665,17.092,17.134999999999998,17.212,17.65,17.614999999999995,17.665,17.971999999999998,17.99,17.826999999999998,18.056999999999995,18.048999999999996,18.048999999999996,17.783999999999995,17.816999999999997,18.135999999999996,18.255999999999997,18.33,18.270999999999997,18.373999999999995,18.604,18.468999999999998,18.468999999999998,18.733,18.525999999999996,17.945999999999998,17.981999999999996,17.836,17.783999999999995,17.743,17.67,17.459,17.927999999999997,18.228999999999996,18.023999999999997,18.109,18.048999999999996,17.854999999999997,17.896,18.083,18.048999999999996,18.041,18.109,18.041,18.191999999999997,18.826999999999998,18.800999999999995,18.740999999999996,18.836,19.040999999999997,19.219999999999995,19.219999999999995,18.989,19.031,19.321999999999996,19.058,19.254999999999995,19.169,19.202,19.219999999999995,19.176999999999996,19.287999999999997,19.98,19.996999999999996,19.893999999999995,20.284999999999997,19.996999999999996,20.031,20.142999999999997,19.642,19.851999999999997,20.127,19.996999999999996,19.971,20.039,20.314999999999998,20.383999999999997,20.392,20.472999999999995,20.341999999999995,20.16,20.229999999999997,20.398999999999997,20.185999999999996,20.022,20.082,20.202,20.058,20.127,20.012999999999998,19.91,19.892999999999997,19.91,19.877,20.1,19.806999999999995,19.877,19.748,19.91,19.859999999999996,20.305999999999997,20.314999999999998,20.202,19.642,19.892999999999997,19.601999999999997,19.522999999999996,18.730999999999998,18.385999999999996,18.515999999999995,18.909999999999997,18.901999999999997,19.126999999999995,19.179,19.194999999999997,19.074999999999996,19.221999999999998,19.437,19.444,19.531999999999996,19.817,19.618999999999996,19.721999999999998,19.678,19.817,20.012999999999998,20.039,20.202,20.296,20.375999999999998,20.5479999 ...

# %%
#probe-pred = model.predict(x_t, batch_size=BATCH_SIZE)
y_pred = model.predict(x_t, batch_size=BATCH_SIZE)
#probe-pred = probe-pred.flatten()
# Out:
# 559/559 [==============================] - 24s 43ms/step

# %%
y_pred
# Out:
# array([[0.15114805],
#        [0.1498307 ],
#        [0.14843667],
#        ...,
#        [0.5603987 ],
#        [0.5615779 ],
#        [0.5626758 ]], dtype=float32)

# %%
# Visualize the prediction
from matplotlib import pyplot as plt
plt.figure()
plt.plot(y_pred)
plt.plot(y_t)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
plt.savefig('result-pred.png')
plt.show()

print_time("program completed ", stime)
# Out:
# program completed  181.0 minutes :  36.0 seconds
